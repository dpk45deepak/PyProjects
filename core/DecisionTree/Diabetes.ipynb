# %% [markdown]
# # Diabetes Decision Tree Regression Prediction

# %%
from sklearn.datasets import load_diabetes
dataset = load_diabetes()

# %%
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
print(dataset.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
# print the dateset's feature
import pandas as pd
df_diabetes = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
# independent and dependent variable
X = df_diabetes
y = dataset.target

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((353, 10), (89, 10), (353,), (89,))

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 252  0.005383 -0.044642  0.059541 -0.056177  0.024574  0.052861 -0.043401
# 416 -0.027310 -0.044642  0.080019  0.098751 -0.002945  0.018101 -0.017629
# 418  0.009016 -0.044642 -0.024529 -0.026328  0.098876  0.094196  0.070730
# 163  0.016281  0.050680  0.072474  0.076958 -0.008449  0.005575 -0.006584
# 253  0.081666 -0.044642  0.033673  0.008101  0.052093  0.056619 -0.017629
# ..        ...       ...       ...       ...       ...       ...       ...
# 369 -0.009147 -0.044642  0.037984 -0.040099 -0.024960 -0.003819 -0.043401
# 320 -0.023677 -0.044642  0.030440 -0.005670  0.082364  0.092004 -0.017629
# 15  -0.052738  0.050680 -0.018062  0.080401  0.089244  0.107662 -0.039719
# 125 -0.005515  0.050680 -0.008362 -0.002228 -0.033216 -0.063630 -0.036038
# 265 -0.034575  0.050680 -0.025607 -0.017135  0.001183 -0.002880  0.008142
#
#            s4        s5        s6
# 252  0.050914 -0.004222 -0.030072
# ...

# %%
# correlation matrix
X_train.corr()
# plot heat map
import seaborn as sns
sns.heatmap(X_train.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Hyperparameter Tuning for Decision Tree Regression

# %%
parameters = model.get_params()
parameters
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter': ['best', 'random'],
    'max_depth': [1, 2, 3, 4, 5, 10, 15,20, 25],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
grid_search = GridSearchCV(estimator=model, param_grid=param, cv=5, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2592 candidates, totalling 12960 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# print all the best parameters found by grid search cv
grid_search.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 3,
#  'max_features': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
# prediction
y_pred = grid_search.predict(X_test)
# y_pred

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R2 Score:', r2)
print('Mean Absolute Error:', mae)
print('Mean Absolute Percentage Error:', mape)
# Out:
# Mean Squared Error: 4141.827300034453
# R2 Score: 0.3374338382594583
# Mean Absolute Error: 51.67395211917576
# Mean Absolute Percentage Error: 0.4918944517550202

# %%
# create model with best parameters and plot the tree
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(criterion='poisson', max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter='random')
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=3, min_samples_leaf=4,
#                       splitter='random')

# %%
# plot the tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plot_tree(model, filled=True, feature_names=dataset.feature_names)
plt.show()
